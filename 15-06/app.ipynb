# %%
import pandas as pd

# %%
df = pd.read_csv("../indoor_air_quality_3.csv")

# %%
df.drop(['Unnamed: 0'],axis=1)
# Out:
#                   Col1                            Col2  \
# 0   Indoor Air Quality              Health & Education
# 1   Indoor Air Quality                        Research
# 2   Indoor Air Quality           Funding Opportunities
# 3   Indoor Air Quality              Careers & Training
# 4   Indoor Air Quality                   News & Events
# 5   Indoor Air Quality                     About NIEHS
# 6   Indoor Air Quality  Your Environment. Your Health.
# 7   Indoor Air Quality                        Webcasts
# 8   Indoor Air Quality                    Introduction
# 9   Indoor Air Quality                    Introduction
# 10  Indoor Air Quality                    Introduction
# 11  Indoor Air Quality                    Introduction
# 12  Indoor Air Quality                    Introduction
# 13  Indoor Air Quality                    Introduction
# 14  Indoor Air Quality                    Introduction
# 15  Indoor Air Quality                    Introduction
# ...

# %%
df.columns
# Out:
# Index(['Indoor Air Quality', 'Health & Education',
# ...
